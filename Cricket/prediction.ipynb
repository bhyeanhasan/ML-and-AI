# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn
import seaborn as sns

# %%
data = pd.read_csv('chirps.csv')
X = data.Chirps_15s
Y = data.Temp_C

# %%
from sklearn.linear_model import LinearRegression

# %%
x_train,x_test,y_train,y_test = sklearn.model_selection.train_test_split(X,Y,test_size=.20,random_state=5)
print(y_train)
# Out:
# 3     23.056
# 24    20.556
# 40    17.222
# 19    20.278
# 4     21.389
# 32    15.556
# 0     26.944
# 5     20.000
# 53    10.417
# 51    17.222
# 42    16.111
# 33    23.889
# 34    22.917
# 28    22.222
# 37    19.722
# 10    12.778
# 49    11.111
# 25    19.444
# 18    20.278
# 29    21.667
# 22    15.000
# 20    20.000
# 44    13.611
# 1     25.833
# 11    24.583
# 13    23.333
# 45    12.778
# 43    16.667
# 46    11.111
# 15    18.889
# 12    23.333
# 7     18.333
# 50    18.333
# 30    20.556
# 27    14.722
# 39    20.556
# 36    21.111
# 8     16.389
# 9     13.889
# 16    25.278
# 38    18.889
# 47    11.667
# 14    22.500
# 35    22.500
# Name: Temp_C, dtype: float64

# %%
model = LinearRegression()

x_train = np.array(x_train).reshape(-1,1)
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
x_test = np.array(x_test).reshape(-1,1)
pred = model.predict(x_test)
ac = np.array( y_test)
# print(ac)
sum =0
p =0
while p < pred.size:
    x = pred[p]-ac[p]
    sum += x
    p+=1
print(sum/p)
# Out:
# 0.26743107905515634

# %%
df = pd.DataFrame(ac,pred)
df
# Out:
#                  0
# 27.271925  25.8330
# 17.003529  17.2220
# 18.780752  19.1670
# 18.756068  18.8890
# 15.670613  16.2500
# 11.474393  10.0000
# 10.733884   9.5833
# 20.557974  21.1110
# 18.830119  18.8890
# 15.275674  15.0000
# 26.087110  25.5560

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(ac,pred)
print(mse)
# Out:
# 0.6168946539179763

# %%
plt.scatter(x_train,y_train,color = "green")
plt.xlabel('Sound')
plt.ylabel('Temperature')
plt.plot(x_train,model.predict(x_train),color="red")
plt.show()

# %%
corrmat = data.corr()
plt.subplots(figsize=(10,10),facecolor="#627D78")
sns.heatmap(corrmat,cmap= "Pastel2",annot=True,square=True, )
# Out:
# C:\Users\NoYoN_CSE16\AppData\Local\Temp\ipykernel_6812\440819679.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = data.corr()
# <Axes: >
