# %%
import seaborn as sns; sns.set(color_codes=True)
import pandas as pd
import matplotlib.pyplot as plt

chirp_data = pd.read_csv("bh.csv")


g = sns.lmplot(x="Result", y="Value", data=chirp_data)
plt.title('Cricket Chirp and Temperature')
plt.show()
