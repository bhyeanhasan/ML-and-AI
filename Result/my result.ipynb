# %%
from matplotlib import pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('myallresult.csv')
df['Weighted Point'] = df['Grade Point'] * df['Credit Hours']
df
# Out:
#    Course Code                                      Course Title  \
# 0      PHY 111                                Physics-I (Repeat)
# 1      PHY 112                               Physics-I Sessional
# 2      CHE 111                                         Chemistry
# 3      CHE 112                               Chemistry Sessional
# 4      MAT 111                                     Mathematics-I
# ..         ...                                               ...
# 67     CCI 421                 Cryptography and Network Security
# 68     CCI 423               Wireless and Cellular Communication
# 69     CIT 421            Computer Graphics and Image Processing
# 70     CIT 422  Computer Graphics and Image Processing Sessional
# 71     CIT 423                       (Optional) Machine Learning
#
#     Credit Hours Grade  Grade Point Semester  Weighted Point
# 0           3.00     C         2.25     L1S1          6.7500
# 1           0.75    B-         2.75     L1S1          2.0625
# ...

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x=df['Course Title'], y=df['Grade Point'], palette="YlGnBu")
plt.xticks(rotation=90)  # Rotate x-axis labels
plt.title("Grade Points by Course Title")
plt.xlabel("Course Title")
plt.ylabel("Grade Point")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/hp/g2__jbrd0p363y959r8xdvtw0000gn/T/ipykernel_86198/1403559234.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=df['Course Title'], y=df['Grade Point'], palette="YlGnBu")

# %%
a_plus = df[df.Grade == 'A+']
print(len(a_plus))
a_plus
# Out:
# 21
#    Course Code                                      Course Title  \
# 7      CIT 111                              Programming Language
# 8      CIT 112                    Programming Language Sessional
# 9      CCE 112                               Engineering Drawing
# 17     CCE 121                       Object Oriented Programming
# 18     CCE 122             Object Oriented Programming Sessional
# 20     CIT 212           Data Structure and Algorithms Sessional
# 24     EEE 211                             Electrical Technology
# 25     EEE 212                   Electrical Technology Sessional
# 30     CCE 224                         Database System Sessional
# 33     CIT 220                           Web Programming Project
# 40     CIT 316                 Artificial Intelligence Sessional
# 45     CCE 314                       Computer Networks Sessional
# 46     CCE 320                   Software Development Project-II
# ...

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x=a_plus['Course Title'], y=a_plus['Grade Point'], palette="YlGnBu")
plt.xticks(rotation=90)  # Rotate x-axis labels
plt.title("A+")
plt.xlabel("Course Title")
plt.ylabel("Grade Point")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/hp/g2__jbrd0p363y959r8xdvtw0000gn/T/ipykernel_86198/2701622049.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=a_plus['Course Title'], y=a_plus['Grade Point'], palette="YlGnBu")

# %%
a_plus_theory = df[(df.Grade == 'A+') & (df['Credit Hours'] == 3)]
print(len(a_plus_theory))
a_plus_theory
# Out:
# 6
#    Course Code                            Course Title  Credit Hours Grade  \
# 7      CIT 111                    Programming Language           3.0    A+
# 17     CCE 121             Object Oriented Programming           3.0    A+
# 24     EEE 211                   Electrical Technology           3.0    A+
# 56     CCE 410                          Project/Thesis           3.0    A+
# 65     CCE 420                        Project/Thesis 2           3.0    A+
# 69     CIT 421  Computer Graphics and Image Processing           3.0    A+
#
#     Grade Point Semester  Weighted Point
# 7           4.0     L1S1            12.0
# 17          4.0     L1S2            12.0
# 24          4.0     L2S1            12.0
# 56          4.0     L4S1            12.0
# 65          4.0     L4S2            12.0
# 69          4.0     L4S2            12.0

# %%
a_plus_lab = df[(df.Grade == 'A+') & (df['Credit Hours'] < 2)]
print(len(a_plus_lab))
a_plus_lab
# Out:
# 15
#    Course Code                                      Course Title  \
# 8      CIT 112                    Programming Language Sessional
# 9      CCE 112                               Engineering Drawing
# 18     CCE 122             Object Oriented Programming Sessional
# 20     CIT 212           Data Structure and Algorithms Sessional
# 25     EEE 212                   Electrical Technology Sessional
# 30     CCE 224                         Database System Sessional
# 33     CIT 220                           Web Programming Project
# 40     CIT 316                 Artificial Intelligence Sessional
# 45     CCE 314                       Computer Networks Sessional
# 46     CCE 320                   Software Development Project-II
# 48     CIT 322                        Operating System Sessional
# 50     CIT 324                 Simulation and Modeling Sessional
# 54     CCE 322     Computer Peripheral and Interfacing Sessional
# ...

# %%
lab = df[df['Credit Hours'] < 2]
print(len(lab))

plt.figure(figsize=(20, 8))
sns.barplot(x=lab['Course Title'], y=lab['Grade Point'], palette="YlGnBu")
plt.xticks(rotation=90)  # Rotate x-axis labels
plt.title("Lab")
plt.xlabel("Course Title")
plt.ylabel("Grade Point")
plt.tight_layout()
plt.show()
# Out:
# 29
# /var/folders/hp/g2__jbrd0p363y959r8xdvtw0000gn/T/ipykernel_86198/3343159772.py:5: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=lab['Course Title'], y=lab['Grade Point'], palette="YlGnBu")

# %%
plt.figure(figsize=(20, 8))
sns.barplot(x=theory['Course Title'], y=theory['Grade Point'], palette="YlGnBu")
plt.xticks(rotation=90)  # Rotate x-axis labels
plt.title("Theory")
plt.xlabel("Course Title")
plt.ylabel("Grade Point")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/hp/g2__jbrd0p363y959r8xdvtw0000gn/T/ipykernel_86198/1382890455.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=theory['Course Title'], y=theory['Grade Point'], palette="YlGnBu")

# %%
a_plus_by_semester = a_plus.groupby('Semester').size().reset_index(name='A+ Count')
a_plus_by_semester
# Out:
#   Semester  A+ Count
# 0     L1S1         3
# 1     L1S2         2
# 2     L2S1         3
# 3     L2S2         2
# 4     L3S1         2
# 5     L3S2         4
# 6     L4S1         2
# 7     L4S2         3

# %%
a_plus_theory_by_semester = a_plus_theory.groupby('Semester').size().reset_index(name='A+ Count')
a_plus_theory_by_semester
# Out:
#   Semester  A+ Count
# 0     L1S1         1
# 1     L1S2         1
# 2     L2S1         1
# 3     L4S1         1
# 4     L4S2         2

# %%
a_plus_lab_by_semester = a_plus_lab.groupby('Semester').size().reset_index(name='A+ Count')
a_plus_lab_by_semester
# Out:
#   Semester  A+ Count
# 0     L1S1         2
# 1     L1S2         1
# 2     L2S1         2
# 3     L2S2         2
# 4     L3S1         2
# 5     L3S2         4
# 6     L4S1         1
# 7     L4S2         1

# %%
theory = df[ df['Credit Hours'] >= 2 ]
lab = df[ df['Credit Hours'] < 2 ]
print(len(theory)+len(lab))
print(sum(df['Credit Hours']))
# Out:
# 72
# 165.0

# %%
avg = (sum(df['Weighted Point']))/sum(df['Credit Hours'])
avg_theory = sum(theory['Weighted Point'])/sum(theory['Credit Hours'])
avg_lab = sum(lab['Weighted Point'])/sum(lab['Credit Hours'])
avg, avg_theory,avg_lab
# Out:
# (3.249242424242424, 3.111328125, 3.7263513513513513)

# %%
plt.figure(figsize=(8, 6))
sns.barplot(x=['Overall_cgpa', 'Theory_cgpa', 'Lab_cgpa'], y=[avg,avg_theory,avg_lab], palette="YlGnBu")
plt.tight_layout()
plt.show()
# Out:
# /var/folders/hp/g2__jbrd0p363y959r8xdvtw0000gn/T/ipykernel_86198/4294313322.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=['Overall_cgpa', 'Theory_cgpa', 'Lab_cgpa'], y=[avg,avg_theory,avg_lab], palette="YlGnBu")

# %%
fame = df[ df['Grade Point'] >= 3]
print(len(fame))
fame
# Out:
# 54
#    Course Code                                       Course Title  \
# 2      CHE 111                                          Chemistry
# 5      EEE 111                       Basic Electrical Engineering
# 7      CIT 111                               Programming Language
# 8      CIT 112                     Programming Language Sessional
# 9      CCE 112                                Engineering Drawing
# 10     PHY 121                                Physics-II (Repeat)
# 11     PHY 122                               Physics-II Sessional
# 13     CIT 121                               Discrete Mathematics
# 14     LCM 121                              Communicative English
# 16     EEE 122           Electronic Device and Circuits Sessional
# 17     CCE 121                        Object Oriented Programming
# 18     CCE 122              Object Oriented Programming Sessional
# 19     CIT 211                      Data Structure and Algorithms
# ...

# %%
fault = df[ df['Grade Point'] == 2 ]
print(len(fault))
fault
# Out:
# 1
#   Course Code   Course Title  Credit Hours Grade  Grade Point Semester  \
# 4     MAT 111  Mathematics-I           3.0     D          2.0     L1S1
#
#    Weighted Point
# 4             6.0

# %%
medium = df[ (df['Grade Point'] < 3) & (df['Grade Point'] > 2) ]
print(len(medium))
medium
# Out:
# 17
#    Course Code                            Course Title  Credit Hours Grade  \
# 0      PHY 111                      Physics-I (Repeat)          3.00     C
# 1      PHY 112                     Physics-I Sessional          0.75    B-
# 3      CHE 112                     Chemistry Sessional          0.75    B-
# 6      EEE 112  Basic Electrical Engineering Sessional          1.50    B-
# 12     MAT 121                          Mathematics-II          3.00    C+
# 15     EEE 121          Electronic Device and Circuits          3.00    C+
# 21     CIT 213                    Software Engineering          3.00    B-
# 23     MAT 211                         Mathematics-III          3.00    C+
# 29     CCE 223                         Database System          3.00    B-
# 42     CCE 311                       Numerical Methods          3.00    C+
# 44     CCE 313                       Computer Networks          3.00    B-
# ...

# %%
course_by_gpa = df.groupby('Grade').size().reset_index(name='Count')
course_by_gpa
# Out:
#   Grade  Count
# 0     A      9
# 1    A+     21
# 2    A-      6
# 3     B      7
# 4    B+     11
# 5    B-      7
# 6     C      3
# 7    C+      7
# 8     D      1

# %%
# Choose a new colormap (e.g., 'Set3')
colors = plt.cm.Set3.colors[:len(course_by_gpa)]

plt.figure(figsize=(8, 8))
plt.pie(
    course_by_gpa['Count'],
    labels=course_by_gpa['Grade'],
    autopct='%1.1f%%',
    startangle=140,
    colors=colors
)

plt.title('Distribution of Courses by Grade Point', fontsize=14)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
# Custom function to display both count and percentage
def autopct_format(pct, allvals):
    count = int(round(pct / 100. * sum(allvals)))
    return f"{pct:.1f}%\n({count})"

# Prepare data
counts = a_plus_by_semester['A+ Count']
labels = a_plus_by_semester['Semester']
colors = plt.cm.Set3.colors[:len(counts)]

# Plot
plt.figure(figsize=(8, 8))
plt.pie(
    counts,
    labels=labels,
    autopct=lambda pct: autopct_format(pct, counts),
    startangle=140,
    colors=colors
)

plt.title('Distribution of A+ Grades by Semester', fontsize=14)
plt.axis('equal')
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt

semester_stats = df.groupby('Semester').agg({
    'Weighted Point': 'sum',
    'Credit Hours': 'sum'
}).reset_index()

semester_stats['CGPA'] = semester_stats['Weighted Point'] / semester_stats['Credit Hours']

# Sort semesters if needed

# Plot
plt.figure(figsize=(10, 4))
plt.plot(semester_stats['Semester'], semester_stats['CGPA'], marker='o', linestyle='-', color='red')
plt.ylim(3.0, 3.5)  # Start Y-axis from 3.0
plt.title("Semester-wise CGPA")
plt.xlabel("Semester")
plt.ylabel("CGPA")
plt.grid(True)
plt.tight_layout()
plt.show()
